# %%
# !gdown --id 1ixh-tv-IKMdNjpoINbILJKGRNwcfH5Tj
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1ixh-tv-IKMdNjpoINbILJKGRNwcfH5Tj
# From (redirected): https://drive.google.com/uc?id=1ixh-tv-IKMdNjpoINbILJKGRNwcfH5Tj&confirm=t&uuid=11d14d81-d9db-4f8f-a5fd-9a63c33bda68
# To: /content/PageSegData.zip
# 100% 40.4M/40.4M [00:01<00:00, 29.4MB/s]

# %%
# !unzip PageSegData
# Out:
# Archive:  PageSegData.zip
#    creating: PageSegData/
#    creating: PageSegData/PageImg/
#   inflating: PageSegData/PageImg/1.JPG
#   inflating: PageSegData/PageImg/10.JPG
#   inflating: PageSegData/PageImg/100.JPG
#   inflating: PageSegData/PageImg/101.JPG
#   inflating: PageSegData/PageImg/102.JPG
#   inflating: PageSegData/PageImg/103.JPG
#   inflating: PageSegData/PageImg/104.JPG
#   inflating: PageSegData/PageImg/105.JPG
#   inflating: PageSegData/PageImg/106.JPG
#   inflating: PageSegData/PageImg/107.JPG
#   inflating: PageSegData/PageImg/108.JPG
#   inflating: PageSegData/PageImg/109.JPG
#   inflating: PageSegData/PageImg/11.JPG
#   inflating: PageSegData/PageImg/110.JPG
#   inflating: PageSegData/PageImg/111.JPG
#   inflating: PageSegData/PageImg/112.JPG
#   inflating: PageSegData/PageImg/113.JPG
#   inflating: PageSegData/PageImg/114.JPG
#   inflating: PageSegData/PageImg/115.JPG
#   inflating: PageSegData/PageImg/116.JPG
#   inflating: PageSegData/PageImg/117.JPG
#   inflating: PageSegData/PageImg/118.JPG
#   inflating: PageSegData/PageImg/119.JPG
#   inflating: PageSegData/PageImg/12.JPG
#   inflating: PageSegData/PageImg/120.JPG
#   inflating: PageSegData/PageImg/121.JPG
#   inflating: PageSegData/PageImg/122.JPG
#   inflating: PageSegData/PageImg/123.JPG
#   inflating: PageSegData/PageImg/124.JPG
#   inflating: PageSegData/PageImg/125.JPG
#   inflating: PageSegData/PageImg/126.JPG
#   inflating: PageSegData/PageImg/127.JPG
#   inflating: PageSegData/PageImg/128.JPG
#   inflating: PageSegData/PageImg/129.JPG
#   inflating: PageSegData/PageImg/13.JPG
#   inflating: PageSegData/PageImg/130.JPG
#   inflating: PageSegData/PageImg/131.JPG
#   inflating: PageSegData/PageImg/132.JPG
#   inflating: PageSegData/PageImg/133.JPG
#   inflating: PageSegData/PageImg/134.JPG
#   inflating: PageSegData/PageImg/135.JPG
#   inflating: PageSegData/PageImg/136.JPG
#   inflating: PageSegData/PageImg/137.JPG
#   inflating: PageSegData/PageImg/138.JPG
#   inflating: PageSegData/PageImg/139.JPG
#   inflating: PageSegData/PageImg/14.JPG
#   inflating: PageSegData/PageImg/140.JPG
#   inflating: PageSegData/PageImg/141.JPG
#   inflating: PageSegData/PageImg/142.JPG
#   inflating: PageSegData/PageImg/143.JPG
#   inflating: PageSegData/PageImg/144.JPG
#   inflating: PageSegData/PageImg/145.JPG
#   inflating: PageSegData/PageImg/146.JPG
#   inflating: PageSegData/PageSeg/114_mask.png
#   inflating: PageSegData/PageSeg/115_mask.png
#   inflating: PageSegData/PageSeg/116_mask.png
#   inflating: PageSegData/PageSeg/117_mask.png
#   inflating: PageSegData/PageSeg/118_mask.png
#   inflating: PageSegData/PageSeg/119_mask.png
#   inflating: PageSegData/PageSeg/11_mask.png
#   inflating: PageSegData/PageSeg/120_mask.png
#   inflating: PageSegData/PageSeg/121_mask.png
#   inflating: PageSegData/PageSeg/122_mask.png
#   inflating: PageSegData/PageSeg/123_mask.png
#   inflating: PageSegData/PageSeg/124_mask.png
#   inflating: PageSegData/PageSeg/125_mask.png
#   inflating: PageSegData/PageSeg/126_mask.png
#   inflating: PageSegData/PageSeg/127_mask.png
#   inflating: PageSegData/PageSeg/128_mask.png
#   inflating: PageSegData/PageSeg/129_mask.png
#   inflating: PageSegData/PageSeg/12_mask.png
#   inflating: PageSegData/PageSeg/130_mask.png
#   inflating: PageSegData/PageSeg/131_mask.png
#   inflating: PageSegData/PageSeg/132_mask.png
#   inflating: PageSegData/PageSeg/133_mask.png
#   inflating: PageSegData/PageSeg/134_mask.png
#   inflating: PageSegData/PageSeg/135_mask.png
#   inflating: PageSegData/PageSeg/136_mask.png
#   inflating: PageSegData/PageSeg/137_mask.png
#   inflating: PageSegData/PageSeg/138_mask.png
#   inflating: PageSegData/PageSeg/139_mask.png
#   inflating: PageSegData/PageSeg/13_mask.png
#   inflating: PageSegData/PageSeg/140_mask.png
#   inflating: PageSegData/PageSeg/141_mask.png
#   inflating: PageSegData/PageSeg/142_mask.png
#   inflating: PageSegData/PageSeg/143_mask.png
#   inflating: PageSegData/PageSeg/144_mask.png
#   inflating: PageSegData/PageSeg/145_mask.png
#   inflating: PageSegData/PageSeg/146_mask.png
#   inflating: PageSegData/PageSeg/147_mask.png
#   inflating: PageSegData/PageSeg/148_mask.png
#   inflating: PageSegData/PageSeg/149_mask.png
#   inflating: PageSegData/PageSeg/14_mask.png
#   inflating: PageSegData/PageSeg/150_mask.png
#   inflating: PageSegData/PageSeg/151_mask.png
#   inflating: PageSegData/PageSeg/152_mask.png
#   inflating: PageSegData/PageSeg/153_mask.png
#   inflating: PageSegData/PageSeg/154_mask.png
#   inflating: PageSegData/PageSeg/155_mask.png
#   inflating: PageSegData/PageSeg/156_mask.png
#   inflating: PageSegData/PageSeg/157_mask.png
#   inflating: PageSegData/PageSeg/158_mask.png
#   inflating: PageSegData/PageSeg/159_mask.png
#   inflating: PageSegData/PageSeg/15_mask.png
#   inflating: PageSegData/PageSeg/160_mask.png
#   inflating: PageSegData/PageSeg/161_mask.png
#   inflating: PageSegData/PageSeg/162_mask.png
#   inflating: PageSegData/PageSeg/163_mask.png
#   inflating: PageSegData/PageSeg/164_mask.png
#   inflating: PageSegData/PageSeg/165_mask.png
#   inflating: PageSegData/PageSeg/166_mask.png
#   inflating: PageSegData/PageSeg/167_mask.png
#   inflating: PageSegData/PageSeg/168_mask.png
#   inflating: PageSegData/PageSeg/169_mask.png
#   inflating: PageSegData/PageSeg/16_mask.png
#   inflating: PageSegData/PageSeg/170_mask.png
#   inflating: PageSegData/PageSeg/171_mask.png
#   inflating: PageSegData/PageSeg/172_mask.png
#   inflating: PageSegData/PageSeg/173_mask.png
#   inflating: PageSegData/PageSeg/174_mask.png
#   inflating: PageSegData/PageSeg/175_mask.png
#   inflating: PageSegData/PageSeg/176_mask.png
#   inflating: PageSegData/PageSeg/177_mask.png
#   inflating: PageSegData/PageSeg/178_mask.png
#   inflating: PageSegData/PageSeg/179_mask.png
#   inflating: PageSegData/PageSeg/17_mask.png
#   inflating: PageSegData/PageSeg/180_mask.png
#   inflating: PageSegData/PageSeg/181_mask.png
#   inflating: PageSegData/PageSeg/182_mask.png
#   inflating: PageSegData/PageSeg/183_mask.png
#   inflating: PageSegData/PageSeg/184_mask.png
#   inflating: PageSegData/PageSeg/185_mask.png
#   inflating: PageSegData/PageSeg/186_mask.png
#   inflating: PageSegData/PageSeg/187_mask.png
#   inflating: PageSegData/PageSeg/188_mask.png
#   inflating: PageSegData/PageSeg/189_mask.png
#   inflating: PageSegData/PageSeg/18_mask.png
#   inflating: PageSegData/PageSeg/190_mask.png
#   inflating: PageSegData/PageSeg/191_mask.png
#   inflating: PageSegData/PageSeg/192_mask.png
#   inflating: PageSegData/PageSeg/193_mask.png
#   inflating: PageSegData/PageSeg/194_mask.png
#   inflating: PageSegData/PageSeg/195_mask.png
#   inflating: PageSegData/PageSeg/196_mask.png
#   inflating: PageSegData/PageSeg/197_mask.png
#   inflating: PageSegData/PageSeg/198_mask.png
#   inflating: PageSegData/PageSeg/199_mask.png
#   inflating: PageSegData/PageSeg/19_mask.png
#   inflating: PageSegData/PageSeg/1_mask.png
#   inflating: PageSegData/PageSeg/200_mask.png
#   inflating: PageSegData/PageSeg/201_mask.png
#   inflating: PageSegData/PageSeg/202_mask.png
#   inflating: PageSegData/PageSeg/203_mask.png
#   inflating: PageSegData/PageSeg/204_mask.png
#   inflating: PageSegData/PageSeg/205_mask.png
#   inflating: PageSegData/PageSeg/206_mask.png
#   inflating: PageSegData/PageSeg/207_mask.png
#   inflating: PageSegData/PageSeg/208_mask.png
#   inflating: PageSegData/PageSeg/209_mask.png
#   inflating: PageSegData/PageSeg/20_mask.png
#   inflating: PageSegData/PageSeg/210_mask.png
#   inflating: PageSegData/PageSeg/211_mask.png
#   inflating: PageSegData/PageSeg/212_mask.png
#   inflating: PageSegData/PageSeg/213_mask.png
#   inflating: PageSegData/PageSeg/214_mask.png
#   inflating: PageSegData/PageSeg/215_mask.png
#   inflating: PageSegData/PageSeg/216_mask.png
#   inflating: PageSegData/PageSeg/217_mask.png
#   inflating: PageSegData/PageSeg/218_mask.png
#   inflating: PageSegData/PageSeg/219_mask.png
#   inflating: PageSegData/PageSeg/21_mask.png
#   inflating: PageSegData/PageSeg/220_mask.png
#   inflating: PageSegData/PageSeg/221_mask.png
#   inflating: PageSegData/PageSeg/222_mask.png
#   inflating: PageSegData/PageSeg/223_mask.png
#   inflating: PageSegData/PageSeg/224_mask.png
#   inflating: PageSegData/PageSeg/225_mask.png
#   inflating: PageSegData/PageSeg/226_mask.png
#   inflating: PageSegData/PageSeg/227_mask.png
#   inflating: PageSegData/PageSeg/228_mask.png
#   inflating: PageSegData/PageSeg/229_mask.png
#   inflating: PageSegData/PageSeg/22_mask.png
#   inflating: PageSegData/PageSeg/230_mask.png
#   inflating: PageSegData/PageSeg/231_mask.png
#   inflating: PageSegData/PageSeg/232_mask.png
#   inflating: PageSegData/PageSeg/233_mask.png
#   inflating: PageSegData/PageSeg/234_mask.png
#   inflating: PageSegData/PageSeg/235_mask.png
#   inflating: PageSegData/PageSeg/236_mask.png
#   inflating: PageSegData/PageSeg/237_mask.png
#   inflating: PageSegData/PageSeg/238_mask.png
#   inflating: PageSegData/PageSeg/239_mask.png
#   inflating: PageSegData/PageSeg/23_mask.png
#   inflating: PageSegData/PageSeg/240_mask.png
#   inflating: PageSegData/PageSeg/241_mask.png
#   inflating: PageSegData/PageSeg/242_mask.png
#   inflating: PageSegData/PageSeg/243_mask.png
#   inflating: PageSegData/PageSeg/244_mask.png
#   inflating: PageSegData/PageSeg/245_mask.png
#   inflating: PageSegData/PageSeg/246_mask.png
#   inflating: PageSegData/PageSeg/247_mask.png
#   inflating: PageSegData/PageSeg/248_mask.png
#   inflating: PageSegData/PageSeg/249_mask.png
#   inflating: PageSegData/PageSeg/24_mask.png
#   inflating: PageSegData/PageSeg/250_mask.png
#   inflating: PageSegData/PageSeg/251_mask.png
#   inflating: PageSegData/PageSeg/252_mask.png
#   inflating: PageSegData/PageSeg/253_mask.png
#   inflating: PageSegData/PageSeg/254_mask.png
#   inflating: PageSegData/PageSeg/255_mask.png
#   inflating: PageSegData/PageSeg/256_mask.png
#   inflating: PageSegData/PageSeg/257_mask.png
#   inflating: PageSegData/PageSeg/258_mask.png
#   inflating: PageSegData/PageSeg/259_mask.png
#   inflating: PageSegData/PageSeg/25_mask.png
#   inflating: PageSegData/PageSeg/260_mask.png
#   inflating: PageSegData/PageSeg/261_mask.png
#   inflating: PageSegData/PageSeg/262_mask.png
#   inflating: PageSegData/PageSeg/263_mask.png
#   inflating: PageSegData/PageSeg/264_mask.png
#   inflating: PageSegData/PageSeg/265_mask.png
#   inflating: PageSegData/PageSeg/266_mask.png
#   inflating: PageSegData/PageSeg/267_mask.png
#   inflating: PageSegData/PageSeg/268_mask.png
#   inflating: PageSegData/PageSeg/269_mask.png
#   inflating: PageSegData/PageSeg/26_mask.png
#   inflating: PageSegData/PageSeg/270_mask.png
#   inflating: PageSegData/PageSeg/271_mask.png
#   inflating: PageSegData/PageSeg/272_mask.png
#   inflating: PageSegData/PageSeg/273_mask.png
#   inflating: PageSegData/PageSeg/274_mask.png
#   inflating: PageSegData/PageSeg/275_mask.png
#   inflating: PageSegData/PageSeg/276_mask.png
#   inflating: PageSegData/PageSeg/277_mask.png
#   inflating: PageSegData/PageSeg/278_mask.png
#   inflating: PageSegData/PageSeg/279_mask.png
#   inflating: PageSegData/PageSeg/27_mask.png
#   inflating: PageSegData/PageSeg/280_mask.png
#   inflating: PageSegData/PageSeg/281_mask.png
#   inflating: PageSegData/PageSeg/282_mask.png
#   inflating: PageSegData/PageSeg/283_mask.png
#   inflating: PageSegData/PageSeg/284_mask.png
#   inflating: PageSegData/PageSeg/285_mask.png
#   inflating: PageSegData/PageSeg/286_mask.png
#   inflating: PageSegData/PageSeg/287_mask.png
#   inflating: PageSegData/PageSeg/288_mask.png
#   inflating: PageSegData/PageSeg/289_mask.png
#   inflating: PageSegData/PageSeg/28_mask.png
#   inflating: PageSegData/PageSeg/290_mask.png
#   inflating: PageSegData/PageSeg/291_mask.png
#   inflating: PageSegData/PageSeg/292_mask.png
#   inflating: PageSegData/PageSeg/293_mask.png
#   inflating: PageSegData/PageSeg/294_mask.png
#   inflating: PageSegData/PageSeg/295_mask.png
#   inflating: PageSegData/PageSeg/296_mask.png
#   inflating: PageSegData/PageSeg/297_mask.png
#   inflating: PageSegData/PageSeg/298_mask.png
#   inflating: PageSegData/PageSeg/299_mask.png
#   inflating: PageSegData/PageSeg/29_mask.png
#   inflating: PageSegData/PageSeg/2_mask.png
#   inflating: PageSegData/PageSeg/300_mask.png
#   inflating: PageSegData/PageSeg/30_mask.png
#   inflating: PageSegData/PageSeg/31_mask.png
#   inflating: PageSegData/PageSeg/32_mask.png
#   inflating: PageSegData/PageSeg/33_mask.png
#   inflating: PageSegData/PageSeg/34_mask.png
#   inflating: PageSegData/PageSeg/35_mask.png
#   inflating: PageSegData/PageSeg/36_mask.png
#   inflating: PageSegData/PageSeg/37_mask.png
#   inflating: PageSegData/PageSeg/38_mask.png
#   inflating: PageSegData/PageSeg/39_mask.png
#   inflating: PageSegData/PageSeg/3_mask.png
#   inflating: PageSegData/PageSeg/40_mask.png
#   inflating: PageSegData/PageSeg/41_mask.png
#   inflating: PageSegData/PageSeg/42_mask.png
#   inflating: PageSegData/PageSeg/43_mask.png
#   inflating: PageSegData/PageSeg/44_mask.png
#   inflating: PageSegData/PageSeg/45_mask.png
#   inflating: PageSegData/PageSeg/46_mask.png
#   inflating: PageSegData/PageSeg/47_mask.png
#   inflating: PageSegData/PageSeg/48_mask.png
#   inflating: PageSegData/PageSeg/49_mask.png
#   inflating: PageSegData/PageSeg/4_mask.png
#   inflating: PageSegData/PageSeg/50_mask.png
#   inflating: PageSegData/PageSeg/51_mask.png
#   inflating: PageSegData/PageSeg/52_mask.png
#   inflating: PageSegData/PageSeg/53_mask.png
#   inflating: PageSegData/PageSeg/54_mask.png
#   inflating: PageSegData/PageSeg/55_mask.png
#   inflating: PageSegData/PageSeg/56_mask.png
#   inflating: PageSegData/PageSeg/57_mask.png
#   inflating: PageSegData/PageSeg/58_mask.png
#   inflating: PageSegData/PageSeg/59_mask.png
#   inflating: PageSegData/PageSeg/5_mask.png
#   inflating: PageSegData/PageSeg/60_mask.png
#   inflating: PageSegData/PageSeg/61_mask.png
#   inflating: PageSegData/PageSeg/62_mask.png
#   inflating: PageSegData/PageSeg/63_mask.png
#   inflating: PageSegData/PageSeg/64_mask.png
#   inflating: PageSegData/PageSeg/65_mask.png
#   inflating: PageSegData/PageSeg/66_mask.png
#   inflating: PageSegData/PageSeg/67_mask.png
#   inflating: PageSegData/PageSeg/68_mask.png
#   inflating: PageSegData/PageSeg/69_mask.png
#   inflating: PageSegData/PageSeg/6_mask.png
#   inflating: PageSegData/PageSeg/70_mask.png
#   inflating: PageSegData/PageSeg/71_mask.png
#   inflating: PageSegData/PageSeg/72_mask.png
#   inflating: PageSegData/PageSeg/73_mask.png
#   inflating: PageSegData/PageSeg/74_mask.png
#   inflating: PageSegData/PageSeg/75_mask.png
#   inflating: PageSegData/PageSeg/76_mask.png
#   inflating: PageSegData/PageSeg/77_mask.png
#   inflating: PageSegData/PageSeg/78_mask.png
#   inflating: PageSegData/PageSeg/79_mask.png
#   inflating: PageSegData/PageSeg/7_mask.png
#   inflating: PageSegData/PageSeg/80_mask.png
#   inflating: PageSegData/PageSeg/81_mask.png
#   inflating: PageSegData/PageSeg/82_mask.png
#   inflating: PageSegData/PageSeg/83_mask.png
#   inflating: PageSegData/PageSeg/84_mask.png
#   inflating: PageSegData/PageSeg/85_mask.png
#   inflating: PageSegData/PageSeg/86_mask.png
#   inflating: PageSegData/PageSeg/87_mask.png
#   inflating: PageSegData/PageSeg/88_mask.png
#   inflating: PageSegData/PageSeg/89_mask.png
#   inflating: PageSegData/PageSeg/8_mask.png
#   inflating: PageSegData/PageSeg/90_mask.png
#   inflating: PageSegData/PageSeg/91_mask.png
#   inflating: PageSegData/PageSeg/92_mask.png
#   inflating: PageSegData/PageSeg/93_mask.png
#   inflating: PageSegData/PageSeg/94_mask.png
#   inflating: PageSegData/PageSeg/95_mask.png
#   inflating: PageSegData/PageSeg/96_mask.png
#   inflating: PageSegData/PageSeg/97_mask.png
#   inflating: PageSegData/PageSeg/98_mask.png
#   inflating: PageSegData/PageSeg/99_mask.png
#   inflating: PageSegData/PageSeg/9_mask.png

# %%
#Importing required libraries.
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
from keras.layers import *
from keras.models import Model
from keras.optimizers import Adam
import random

image_list=os.listdir('/content/PageSegData/PageImg/')
image_list=[filename.split(".")[0]for filename in image_list]

def visualize(img,seg_img):
    """
    Visualizes image
    """
    plt.figure(figsize=(20,20))
    plt.subplot(1,2,1)
    plt.imshow(img)
    plt.title('Image')
    plt.subplot(1,2,2)
    plt.imshow(seg_img,cmap='gray')
    plt.title('Segmented Image')
    plt.show()

def get_segmented_img(img,n_classes):
    """
    Loads in the segmented image and create suitable segmentation label.
    """
    seg_labels=np.zeros((512,512,1))
    img=cv2.resize(img,(512,512))
    img=img[:,:,0]
    cl_list=[0,24]


    seg_labels[:,:,0]=(img!=0).astype(int)


    return seg_labels
def preprocess_img(img):
    img=cv2.resize(img,(512,512))
    return img

def batch_generator(filelist,n_classes,batch_size):
  while True:
    X=[]
    Y=[]
    for i in range(batch_size):
      fn=random.choice(filelist)
      img=cv2.imread(f'/content/PageSegData/PageImg/{fn}.JPG',0)
      ret,img=cv2.threshold(img,150,255,cv2.THRESH_BINARY_INV)
      img=cv2.resize(img,(512,512))
      img=np.expand_dims(img,axis=-1)
      #img = np.stack((img,)*3, axis=-1)
      img=img/255

      seg=cv2.imread(f'/content/PageSegData/PageSeg/{fn}_mask.png',1)
      seg=get_segmented_img(seg,n_classes)

      X.append(img)
      Y.append(seg)
    yield np.array(X),np.array(Y)

# %%
image_list[0]

# %%
img=cv2.imread('/content/PageSegData/PageImg/'+image_list[0]+'.JPG',1)
seg=cv2.imread('/content/PageSegData/PageSeg/'+image_list[0]+'_mask.png',1)

visualize(img,seg)

# %%
def unet(pretrained_weights = None,input_size = (512,512,1)):
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

    model = Model(inputs,conv10)

    model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy'])

    if(pretrained_weights):
    	model.load_weights(pretrained_weights)

    return model

model=unet()
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 1)]        0         []
#
#  conv2d (Conv2D)             (None, 512, 512, 64)         640       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 512, 512, 64)         36928     ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 256, 256, 64)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 128)        73856     ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 128)        147584    ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 128, 128, 128)        0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 256)        295168    ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 256)        590080    ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 64, 256)          0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 512)          1180160   ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 512)          2359808   ['conv2d_6[0][0]']
#
#  dropout (Dropout)           (None, 64, 64, 512)          0         ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 32, 512)          0         ['dropout[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 1024)         4719616   ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 1024)         9438208   ['conv2d_8[0][0]']
#
#  dropout_1 (Dropout)         (None, 32, 32, 1024)         0         ['conv2d_9[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 64, 64, 1024)         0         ['dropout_1[0][0]']
#  D)
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 512)          2097664   ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)   (None, 64, 64, 1024)         0         ['dropout[0][0]',
#                                                                      'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 512)          4719104   ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 512)          2359808   ['conv2d_11[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 128, 128, 512)        0         ['conv2d_12[0][0]']
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 256)        524544    ['up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate  (None, 128, 128, 512)        0         ['conv2d_5[0][0]',
#  )                                                                   'conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 256)        1179904   ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 256)        590080    ['conv2d_14[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 256, 256, 256)        0         ['conv2d_15[0][0]']
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 256, 256, 128)        131200    ['up_sampling2d_2[0][0]']
#
#  concatenate_2 (Concatenate  (None, 256, 256, 256)        0         ['conv2d_3[0][0]',
#  )                                                                   'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 256, 256, 128)        295040    ['concatenate_2[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 128)        147584    ['conv2d_17[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 512, 512, 128)        0         ['conv2d_18[0][0]']
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 512, 512, 64)         32832     ['up_sampling2d_3[0][0]']
#
#  concatenate_3 (Concatenate  (None, 512, 512, 128)        0         ['conv2d_1[0][0]',
#  )                                                                   'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 512, 512, 64)         73792     ['concatenate_3[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 512, 512, 64)         36928     ['conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 512, 512, 2)          1154      ['conv2d_21[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 512, 512, 1)          3         ['conv2d_22[0][0]']
#
# ==================================================================================================
# Total params: 31031685 (118.38 MB)
# Trainable params: 31031685 (118.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
random.shuffle(image_list)
file_train=image_list[0:int(0.75*len(image_list))]
file_test=image_list[int(0.75*len(image_list)):]

# %%
img,seg=next(batch_generator(file_train,2,1))
plt.imshow(np.squeeze(seg[:,:,:,0],axis=0),cmap='gray')

# %%
from keras.callbacks import ModelCheckpoint
mc = ModelCheckpoint('weights{epoch:08d}.h5',
                                     save_weights_only=True, period=1)
model.fit_generator(batch_generator(file_train,2,2),epochs=3,steps_per_epoch=1000,validation_data=batch_generator(file_test,2,2),
                    validation_steps=400,callbacks=[mc],shuffle=1)

# %%
import seaborn as sns
img=cv2.imread(f'/content/1.png',0)
ret,img=cv2.threshold(img,150,255,cv2.THRESH_BINARY_INV)
img=cv2.resize(img,(512,512))
img= np.expand_dims(img,axis=-1)

# %%
img=np.expand_dims(img,axis=0)
pred=model.predict(img)
pred=np.squeeze(np.squeeze(pred,axis=0),axis=-1)
plt.imshow(pred,cmap='gray')
# Out:
# 1/1 [==============================] - 5s 5s/step

# %%
plt.imsave('test_img_mask.JPG',pred)

# %%
coordinates=[]

# %%
import cv2
img = cv2.imread('/content/test_img_mask.JPG',0)
cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU,img)
ori_img=cv2.imread('/content/1.png')
ori_img=cv2.resize(ori_img,(512,512))
contours, hier = cv2.findContours(img, cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
for c in contours:
    # get the bounding rect
    x, y, w, h = cv2.boundingRect(c)
    # draw a white rectangle to visualize the bounding rect
    cv2.rectangle(ori_img, (x, y), (x+w,y+h), 255, 1)
    coordinates.append([x,y,(x+w),(y+h)])

#cv2.drawContours(img, contours, -1, (255, 255, 0), 1)

cv2.imwrite("output.png",ori_img)
# Out:
# True

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/content/20.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

h, w, c = img.shape

if w > 1000:

    new_w = 1000
    ar = w/h
    new_h = int(new_w/ar)

    img = cv2.resize(img, (new_w, new_h), interpolation = cv2.INTER_AREA)
plt.imshow(img);

# %%
def thresholding(image):
    img_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    ret,thresh = cv2.threshold(img_gray,127,255,cv2.THRESH_BINARY_INV)
    plt.imshow(thresh, cmap='gray')
    return thresh

thresh_img = thresholding(img);

# %%
#dilation
kernel = np.ones((4,16), np.uint8)
dilated = cv2.dilate(thresh_img, kernel, iterations = 1)
plt.imshow(dilated, cmap='gray');

# %%
dark_grey_value = 40
light_grey_value = 0
mask_grey = np.where(dilated > 240, dark_grey_value, light_grey_value).astype(np.uint8)
cv2.imwrite("20_mask.png",mask_grey)
plt.imshow(mask_grey);
