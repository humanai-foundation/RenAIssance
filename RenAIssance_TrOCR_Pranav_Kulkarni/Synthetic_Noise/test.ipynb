# %%
import pandas as pd

# %%
df = pd.read_csv("noisy_sentence_pairs.tsv", sep="\t", header=None)

# %%
df.head(10)
# Out:
#                                                    0  \
# 0                                              Input
# 1                       EXHORTACION\na los Maesfróſ.
# 2  EMULANDO lás\nobligaciones, y\nzelo de las bue...
# 3  Ante todas cosas. lo que deven creer y  entend...
# 4  Ay ynfinitos cathecismos con\ndeclaraciones de...
# 5  Para ecta obra me ha parecido \nelegir de las ...
# 6  Todó efl0 lo dedico à mi5\nHlgos, pára quc vie...
# 7  Y sea lo primero que les pido, encomienden muc...
# 8  Poco diFerencia de eslo lo que dize Sañ\nAgust...
# 9  As5í lo\nmanifiesfo aque1 mandalo de Dios, \nq...
#
#                                                    1
# 0                                             Target
# 1                       EXHORTACION\na los Maestros.
# 2  EMULANDO las\nobligaciones, y\nzelo de las bue...
# 3  Ante todas cosas lo que deven creer y entender...
# 4  Ay infinitos cathecismos con\ndeclaraciones de...
# 5  Para esta obra me ha parecido \nelegir de las ...
# ...
